# %%
import pandas
from pandas import DataFrame
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pandas.read_csv('cost_revenue_clean.csv')

# %%
data.describe()
# Out:
#        production_budget_usd  worldwide_gross_usd
# count           5.034000e+03         5.034000e+03
# mean            3.290784e+07         9.515685e+07
# std             4.112589e+07         1.726012e+08
# min             1.100000e+03         2.600000e+01
# 25%             6.000000e+06         7.000000e+06
# 50%             1.900000e+07         3.296202e+07
# 75%             4.200000e+07         1.034471e+08
# max             4.250000e+08         2.783919e+09

# %%
x = DataFrame(data, columns=['production_budget_usd'])
y = DataFrame(data, columns=['worldwide_gross_usd'])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y, alpha=0.3)
plt.title('Fiilm Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('World Wide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()

# %%
regression = LinearRegression()
regression.fit(x, y)
x_reg = x.values

# %% [markdown]
# Slope Coefficient:

# %%
theta = regression.coef_
theta
# Out:
# array([[3.11150918]])

# %%
#intercept
interc = regression.intercept_
interc
# Out:
# array([-7236192.72913958])

# %%
plt.figure(figsize=(10,6))
plt.scatter(x,y, alpha=0.3)
plt.plot(x_reg, regression.predict(x_reg), color="red", linewidth=3)
plt.title('Fiilm Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.ylabel('World Wide Gross $')
plt.ylim(0,3000000000)
plt.xlim(0,450000000)
plt.show()
# Out:
# C:\Users\mhudz\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
b = 50000000

# %%
pred_reg = interc + theta * b

# %%
pred_reg
# Out:
# array([[1.48339266e+08]])

# %%
1.48339266e+08
# Out:
# 148339266.0

# %%
regression.score(x, y)
# Out:
# 0.5496485356985729
